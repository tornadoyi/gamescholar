# %%
from process import Process
import sys
num_workers = 1
sys.argv = [sys.executable, '--index={}'.format(num_workers), '--num-workers={}'.format(num_workers), '--worker-path=a3c.py', '--mode=play', '--render=True', '--auto-save=False']
import option
cluster = option.cluster
#cluster['worker'] = option.create_hosts('127.0.0.1', 30000, 20)
process = Process(option.args, cluster)
process()
# Out:
# [2017-08-22 15:01:26,981] Making new env: SW1-1-VS-N-v0
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ff51a0c8-de47-45d1-b65e-dd89a9371ce6">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0768ac9d-7f88-409a-a0f4-8cc198cdd3f6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0768ac9d-7f88-409a-a0f4-8cc198cdd3f6");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("530695f7-b775-451b-98e7-7336941626b5", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0768ac9d-7f88-409a-a0f4-8cc198cdd3f6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0768ac9d-7f88-409a-a0f4-8cc198cdd3f6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2e610d70-05d8-40f0-8611-6f8b3dfceaee":{"roots":{"references":[{"attributes":{"plot":null,"text":"Player HP/MP/EP"},"id":"bfe53315-7134-433e-841a-74029d0087f3","type":"Title"},{"attributes":{"text_align":"center","text_alpha":{"value":0.5},"text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"5pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"52095898-f819-45c3-be03-0b7fbeb476f6","type":"Text"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7b059907-2f8f-4b2f-b55c-1ef03961eb0c","type":"PanTool"},{"id":"9e36949a-f18a-442f-9b49-4678a9640445","type":"WheelZoomTool"},{"id":"c7d814d2-202b-4ba9-89ff-225903d9b287","type":"BoxZoomTool"},{"id":"49026ed4-2061-4acc-bded-f3b4ed95b261","type":"SaveTool"},{"id":"1cdd2dc6-b026-47a1-8f63-8faca5f80b62","type":"ResetTool"},{"id":"09c51e93-b697-4517-af96-4826b31809dc","type":"HelpTool"}]},"id":"511d2777-ac1a-4e43-9545-ff16d882edb4","type":"Toolbar"},{"attributes":{"plot":{"id":"59be0897-5db9-4fb8-bb98-079dae293aa6","subtype":"Figure","type":"Plot"}},"id":"f84d0481-bc60-4ce3-98eb-796a9d05e32f","type":"SaveTool"},{"attributes":{"overlay":{"id":"ef49e003-5e68-49f8-a421-d139e124edef","type":"BoxAnnotation"},"plot":{"id":"7aae4660-e221-4927-b03b-0e113a21f389","subtype":"Figure","type":"Plot"}},"id":"5b3f1d26-23ff-4b41-8ba1-0bcc66c2b955","type":"BoxZoomTool"},{"attributes":{"children":[{"id":"59be0897-5db9-4fb8-bb98-079dae293aa6","subtype":"Figure","type":"Plot"},{"id":"61b4e0a1-e9c8-4c31-a08f-886357b79599","subtype":"Figure","type":"Plot"}]},"id":"fa717bd0-42b2-486e-8ecc-d1c475a57005","type":"Column"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":0.9},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":0.9},"x":{"field":"x"},"y":{"field":"y"}},"id":"731dc9cf-57fb-467e-bb8a-d85341bb3fd8","type":"Rect"},{"attributes":{"formatter":{"id":"02245a2a-cb3a-41da-92c5-eb9542713433","type":"BasicTickFormatter"},"plot":{"id":"66a7c431-1ba3-43c1-81a7-165102cec638","subtype":"Figure","type":"Plot"},"ticker":{"id":"7e6d801c-570e-4bd1-b749-428e8aac5167","type":"BasicTicker"}},"id":"672ed7d8-8236-4da4-a3b2-f9864c35604d","type":"LinearAxis"},{"attributes":{},"id":"604e0caf-a7a2-48fc-aad0-d04e12a530a3","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"14d687e7-8b73-4aa4-9b2d-f48c389ba568","type":"DataRange1d"},{"attributes":{"above":[{"id":"723555c2-c9d8-4009-803d-25d2fcc6ae82","type":"LinearAxis"}],"left":[{"id":"672ed7d8-8236-4da4-a3b2-f9864c35604d","type":"LinearAxis"}],"plot_height":577,"plot_width":400,"renderers":[{"id":"723555c2-c9d8-4009-803d-25d2fcc6ae82","type":"LinearAxis"},{"id":"d99e026d-3621-4f5a-a993-1864f90796b8","type":"Grid"},{"id":"672ed7d8-8236-4da4-a3b2-f9864c35604d","type":"LinearAxis"},{"id":"8952325b-3acd-4f64-bf4e-36c36b797eea","type":"Grid"},{"id":"d8d07703-2af0-475a-964f-57e01815031e","type":"BoxAnnotation"},{"id":"9611deba-886d-415b-8d7b-6a9848f17528","type":"GlyphRenderer"},{"id":"33be31d2-743f-4d68-b3e6-1353c2818dd3","type":"GlyphRenderer"},{"id":"dfe6e090-9469-4b0f-9b3b-c4ad430b7e6d","type":"GlyphRenderer"}],"title":{"id":"10fc1f5b-041f-42e0-825a-f42c14bc651d","type":"Title"},"tool_events":{"id":"e7131b60-41dd-4054-ba30-9e23019602d5","type":"ToolEvents"},"toolbar":{"id":"440c604f-b7d4-4deb-b055-84b97da238ed","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"b5592172-0c7c-468f-bbbe-bf5e6ab5502f","type":"Range1d"},"y_range":{"id":"de3c8965-cb7e-4f3b-8fee-25da3324af9a","type":"Range1d"}},"id":"66a7c431-1ba3-43c1-81a7-165102cec638","subtype":"Figure","type":"Plot"},{"attributes":{"overlay":{"id":"8efcbecb-36ba-46eb-98d8-cb981491cbe8","type":"BoxAnnotation"},"plot":{"id":"61b4e0a1-e9c8-4c31-a08f-886357b79599","subtype":"Figure","type":"Plot"}},"id":"b9862897-7bdc-4da7-be5f-80178b2113ae","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"791b40fa-dd31-4c94-bc37-4a028 ...
