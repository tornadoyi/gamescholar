# %%
import hra
hra.run(True)
# Out:
# [2017-07-12 11:54:00,181] Making new env: tiny-rpg-man-v0
# [2017-07-12 11:54:02,303] Making new env: tiny-rpg-man-v0
# [2017-07-12 11:54:04,220] Making new env: tiny-rpg-man-v0
# [2017-07-12 11:54:06,242] Making new env: tiny-rpg-man-v0
# [2017-07-12 11:54:08,027] Making new env: tiny-rpg-man-v0
# [2017-07-12 11:54:09,979] Making new env: tiny-rpg-man-v0
# [2017-07-12 11:54:12,066] Making new env: tiny-rpg-man-v0
# [2017-07-12 11:54:14,036] Making new env: tiny-rpg-man-v0
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e41df444-619b-4d70-8fde-bbfb115fe0f4">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="42fa7ef6-ad1a-4dbf-a2f6-3c46d3b8f78d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
# ...
