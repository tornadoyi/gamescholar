# %%
import a3c
a3c.run(True)
# Out:
# [2017-07-06 16:18:54,193] Making new env: tiny-rpg-man-v0
# [2017-07-06 16:18:54,289] Making new env: tiny-rpg-man-v0
# [2017-07-06 16:18:54,805] Making new env: tiny-rpg-man-v0
# [2017-07-06 16:18:55,177] Making new env: tiny-rpg-man-v0
# [2017-07-06 16:18:55,558] Making new env: tiny-rpg-man-v0
# [2017-07-06 16:18:56,002] Making new env: tiny-rpg-man-v0
# [2017-07-06 16:18:56,375] Making new env: tiny-rpg-man-v0
# [2017-07-06 16:18:56,749] Making new env: tiny-rpg-man-v0
# [2017-07-06 16:18:57,210] Making new env: tiny-rpg-man-v0
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5d5f9f6a-dfc1-4f85-be67-84e17abe6a20">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9446d109-9d8b-44bf-a97f-d9229cfd948e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
# ...
