# %%
import a3c
a3c.run(True)
# Out:
# [2017-06-23 17:09:24,245] Making new env: tiny-rpg-man-v0
# [2017-06-23 17:09:24,341] Making new env: tiny-rpg-man-v0
# [2017-06-23 17:09:24,743] Making new env: tiny-rpg-man-v0
# [2017-06-23 17:09:25,025] Making new env: tiny-rpg-man-v0
# [2017-06-23 17:09:25,309] Making new env: tiny-rpg-man-v0
# [2017-06-23 17:09:25,658] Making new env: tiny-rpg-man-v0
# [2017-06-23 17:09:25,954] Making new env: tiny-rpg-man-v0
# [2017-06-23 17:09:26,234] Making new env: tiny-rpg-man-v0
# [2017-06-23 17:09:26,589] Making new env: tiny-rpg-man-v0
# [2017-06-23 17:09:26,874] Making new env: tiny-rpg-man-v0
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d83f2d87-9f34-4536-9f13-30df145fd5e3">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5ec5db07-ff30-446e-ad80-8ccddef8ee96"></div>
#     </div>
# <script type="text/javascript">
#
# ...
