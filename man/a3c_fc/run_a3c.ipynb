# %%
import a3c
a3c.run(True)
# Out:
# [2017-06-23 17:38:22,734] Making new env: tiny-rpg-man-v0
# [2017-06-23 17:38:22,840] Making new env: tiny-rpg-man-v0
# [2017-06-23 17:38:23,262] Making new env: tiny-rpg-man-v0
# [2017-06-23 17:38:23,588] Making new env: tiny-rpg-man-v0
# [2017-06-23 17:38:23,892] Making new env: tiny-rpg-man-v0
# [2017-06-23 17:38:24,253] Making new env: tiny-rpg-man-v0
# [2017-06-23 17:38:24,554] Making new env: tiny-rpg-man-v0
# [2017-06-23 17:38:24,839] Making new env: tiny-rpg-man-v0
# [2017-06-23 17:38:25,197] Making new env: tiny-rpg-man-v0
# [2017-06-23 17:38:25,480] Making new env: tiny-rpg-man-v0
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9acedd33-4b9a-4d3f-a128-669b13e9c8b7">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cb14edb5-ef5c-4067-b4ed-9401981e8aeb"></div>
#     </div>
# <script type="text/javascript">
#
# ...
