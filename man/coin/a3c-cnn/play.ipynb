# %%
# human play
import keyboard
keyboard.run(True)

# %%
# play
from process import Process
import sys
sys.argv = [sys.executable, '--index=8', '--worker-path=a3c.py', '--num-workers=8', '--mode=play', '--render=True', '--auto-save=False']
import option
cluster = option.cluster
#cluster['worker'] = option.create_hosts('127.0.0.1', 30000, 20)
process = Process(option.args, cluster)
process()
# Out:
# [2017-08-04 17:37:40,224] Making new env: tiny-rpg-man-v0
# INFO:tensorflow:Starting queue runners.
# [2017-08-04 17:38:02,300] Starting queue runners.
# [2017-08-04 17:38:02,313] Starting training at step=783610
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9d66e6ce-9793-4a96-86c5-87a5cd7a08a7">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="323ad82b-20d2-4916-879e-56d7ce56240c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("323ad82b-20d2-4916-879e-56d7ce56240c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("96aec71a-ef43-42ad-b97a-4e92b41aeeba", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("323ad82b-20d2-4916-879e-56d7ce56240c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '323ad82b-20d2-4916-879e-56d7ce56240c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"920e396c-f8c6-4c9d-b631-f5d341d5cd2f":{"roots":{"references":[{"attributes":{"align":"center","background_fill_color":{"value":"black"},"plot":null,"text":"running ep reward: ","text_color":{"value":"green"},"text_font_size":{"value":"20px"}},"id":"d8071938-2eca-4c6f-8277-eefc11a62c74","type":"Title"},{"attributes":{},"id":"164cc54a-30b0-4cb4-8944-b988ffada714","type":"BasicTickFormatter"},{"attributes":{},"id":"b456bf26-b229-4f11-b429-b54c1ff79cd6","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.3},"line_color":{"value":"navy"},"line_dash":[2,4],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"a6d806f8-4b7f-4d5a-8cf8-018931d4beeb","type":"Line"},{"attributes":{"callback":null},"id":"88c1f9a5-55dd-4522-900b-ebf50fe9c9e3","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"7291e933-66c1-45c4-acaf-f95df175c1db","subtype":"Figure","type":"Plot"},"ticker":{"id":"bfc5739f-8f35-47cd-839e-93f68d144564","type":"BasicTicker"}},"id":"635f0a2b-3bbe-4c67-9142-62b68c5683da","type":"Grid"},{"attributes":{"plot":{"id":"7291e933-66c1-45c4-acaf-f95df175c1db","subtype":"Figure","type":"Plot"},"ticker":{"id":"08370e6b-4db4-4347-8250-f649e2b588b6","type":"BasicTicker"}},"id":"03a382b4-fd17-4d3b-8a07-4c2619506e43","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"182daeac-7abc-4021-833e-a87ad165586f","subtype":"Figure","type":"Plot"},"ticker":{"id":"28350436-543c-4251-a37c-02f88e2bb6f4","type":"BasicTicker"}},"id":"33df7a47-5c0a-45d5-8bab-86db95e2b38d","type":"Grid"},{"attributes":{"callback":null,"end":11.0,"start":-1.0},"id":"8561e9f0-0a4e-4a0f-9c13-b7ca1975446e","type":"Range1d"},{"attributes":{"plot":{"id":"182daeac-7abc-4021-833e-a87ad165586f","subtype":"Figure","type":"Plot"}},"id":"74dfbd2c-f114-4ee9-b170-7e23b6589be4","type":"ResetTool"},{"attributes":{"align":"center","background_fill_color":{"value":"blue"},"plot":null,"text":"step #0","text_color":{"value":"orange"},"text_font_size":{"value":"25px"}},"id":"3f1c963e-dc70-4863-acc5-4f06a3bd96f9","type":"Title"},{"attributes":{"plot":{"id":"182daeac-7abc-4021-833e-a87ad165586f","subtype":"Figure","type":"Plot"}},"id":"641251a4-fc1a-4356-93ed-e80921d16dbb","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"577c1b9e-bf0f-4235-925f-6c1db28d7de1","type":"BasicTickFormatter"},"plot":{"id":"7291e933-66c1-45c4-acaf-f95df175c1db","subtype":"Figure","type":"Plot"},"ticker":{"id":"08370e6b-4db4-4347-8250-f649e2b588b6","type":"BasicTicker"}},"id":"d236abf1-a704-45ad-8bb7-2cadf25b8b70","type":"LinearAxis"},{"attributes":{"formatter":{"id":"50320e95-ca2f-4ce2-a255-5e5902b101e3","type":"BasicTickFormatter"},"plot":{"id":"7291e933-66c1-45c4-acaf-f95df175c1db","subtype":"Figure","type":"Plot"},"ticker":{"id":"bfc5739f-8f35-47cd-839e-93f68d144564","type":"BasicTicker"}},"id":"d1b73ea6-dcc7-4e37-9077-a0961b1936c4","type":"LinearAxis"},{"attributes":{},"id":"08370e6b-4db4-4347-8250-f649e2b588b6","type":"BasicTicker"},{"attributes":{"children":[{"id":"abc4ed23-b2fb-4660-b505-50ad89dbbb62","type":"ToolbarBox"},{"id":"828c14a8-1f60-448e-b6c4-36da463b942a","type":"Column"}]},"id":"5426594b-92f5-4c25-8419-61855a6eed1c","type":"Column"},{"attributes":{},"id":"28350436-543c-4251-a37c-02f88e2bb6f4","type":"BasicTicker"},{"attributes":{"plot":{"id":"7291e933-66c1-45c4-acaf-f95df175c1db","subtype":"Figure","type":"Plot"}},"id":"7d96908c-6408-457b-ad7b-f1f0cade1e9c","type":"PanTool"},{"attributes":{"sizing_mode":"scale_width","toolbar_location":"above","tools":[{"id":"953a7c27-5e86-49c4-b593-810c9dba4ded","type":"PanTool"},{"id":"641251a4-fc1a-4356-93ed-e80921d16dbb","type":"WheelZoomTool"},{"id":"a0e64340-d3bb-4a55-8866-91776eadc044","type":"BoxZoomTool"},{"id":"e656d09b-221f-4082-a462-aeddacb4e334","type":"SaveTool"},{"id":"74dfbd2c-f114-4ee9-b170-7e23b6589be4","type":"ResetTool"},{"id":"8d377a44-3d14-48bb-b6e6-50b495cb580f","type":"HelpTool"},{"id":"7d96908c-6408-457b-ad7b-f1f0cade1e9c","type":"PanTool"},{"id":"4ff7d06f-623d-41 ...
# INFO:tensorflow:Error reported to Coordinator: <class 'tensorflow.python.framework.errors_impl.AbortedError'>, RecvTensor expects a different device incarnation: 8032246616154174070 vs. 11642506655348026483. Your worker job was probably restarted. Check your worker job for the reason why it was restarted.
# 	 [[Node: global/Variable_S39 = _Recv[_start_time=0, client_terminated=false, recv_device="/job:worker/replica:0/task:8/cpu:0", send_device="/job:ps/replica:0/task:0/cpu:0", send_device_incarnation=8032246616154174070, tensor_name="edge_17_global/Variable", tensor_type=DT_DOUBLE, _device="/job:worker/replica:0/task:8/cpu:0"]()]]
# [2017-08-04 18:09:10,087] Error reported to Coordinator: <class 'tensorflow.python.framework.errors_impl.AbortedError'>, RecvTensor expects a different device incarnation: 8032246616154174070 vs. 11642506655348026483. Your worker job was probably restarted. Check your worker job for the reason why it was restarted.
# 	 [[Node: global/Variable_S39 = _Recv[_start_time=0, client_terminated=false, recv_device="/job:worker/replica:0/task:8/cpu:0", send_device="/job:ps/replica:0/task:0/cpu:0", send_device_incarnation=8032246616154174070, tensor_name="edge_17_global/Variable", tensor_type=DT_DOUBLE, _device="/job:worker/replica:0/task:8/cpu:0"]()]]
# ---------------------------------------------------------------------------
# AbortedError                              Traceback (most recent call last)
# /Applications/anaconda/envs/python35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#
# /Applications/anaconda/envs/python35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#
# /Applications/anaconda/envs/python35/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# /Applications/anaconda/envs/python35/lib/python3.5/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# AbortedError: RecvTensor expects a different device incarnation: 8032246616154174070 vs. 11642506655348026483. Your worker job was probably restarted. Check your worker job for the reason why it was restarted.
# 	 [[Node: global/Variable_S39 = _Recv[_start_time=0, client_terminated=false, recv_device="/job:worker/replica:0/task:8/cpu:0", send_device="/job:ps/replica:0/task:0/cpu:0", send_device_incarnation=8032246616154174070, tensor_name="edge_17_global/Variable", tensor_type=DT_DOUBLE, _device="/job:worker/replica:0/task:8/cpu:0"]()]]
#
# During handling of the above exception, another exception occurred:
#
# AbortedError                              Traceback (most recent call last)
# <ipython-input-1-13bae9c6e0b5> in <module>()
#       7 #cluster['worker'] = option.create_hosts('127.0.0.1', 30000, 20)
#       8 process = Process(option.args, cluster)
# ----> 9 process()
#
# ~/Projects/ML/gamescholar/man/coin/a3c-cnn/process.py in __call__(self)
#      30         if args.job_name == "worker":
#      31             worker = self._load_worker()
# ---> 32             worker.run(server, args)
#      33
#      34         else:
#
# ~/Projects/ML/gamescholar/man/coin/a3c-cnn/a3c.py in run(server, args)
#      87     with sv.managed_session(server.target, config=config) as sess, sess.as_default():
#      88         logging.info("Starting training at step=%d", sess.run(global_step))
# ---> 89         worker(sess)
#      90
#      91
#
# ~/Projects/ML/gamescholar/man/coin/a3c-cnn/agent.py in __call__(self, sess)
#     182
#     183                 if done:
# --> 184                     self._end()
#     185                     break
#     186
#
# ~/Projects/ML/gamescholar/man/coin/a3c-cnn/agent.py in _end(self)
#     213         summary, global_step = self.sess.run([self.summary_op, self.global_step], feed_dict = {
#     214             self.reward: self.v_reward,
# --> 215             self.running_reward: self.v_runing_reward,
#     216         })
#     217         self.summary_writer.add_summary(tf.Summary.FromString(summary), global_step)
#
# /Applications/anaconda/envs/python35/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Applications/anaconda/envs/python35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# /Applications/anaconda/envs/python35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Applications/anaconda/envs/python35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1150         except KeyError:
#    1151           pass
# -> 1152       raise type(e)(node_def, op, message)
#    1153
#    1154   def _extend_graph(self):
#
# AbortedError: RecvTensor expects a different device incarnation: 8032246616154174070 vs. 11642506655348026483. Your worker job was probably restarted. Check your worker job for the reason why it was restarted.
# 	 [[Node: global/Variable_S39 = _Recv[_start_time=0, client_terminated=false, recv_device="/job:worker/replica:0/task:8/cpu:0", send_device="/job:ps/replica:0/task:0/cpu:0", send_device_incarnation=8032246616154174070, tensor_name="edge_17_global/Variable", tensor_type=DT_DOUBLE, _device="/job:worker/replica:0/task:8/cpu:0"]()]]
