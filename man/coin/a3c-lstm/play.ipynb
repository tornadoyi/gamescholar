# %%
# human play
import keyboard
keyboard.run(True)

# %%
# play
from process import Process
import sys
sys.argv = [sys.executable, '--index=10', '--worker-path=a3c.py', '--mode=play', '--render=True', '--auto-save=False']
import option
cluster = option.cluster
#cluster['worker'] = option.create_hosts('127.0.0.1', 30000, 20)
process = Process(option.args, cluster)
process()
# Out:
# [2017-07-30 18:28:58,277] Making new env: tiny-rpg-man-v0
# INFO:tensorflow:Starting queue runners.
# [2017-07-30 18:29:09,914] Starting queue runners.
# [2017-07-30 18:29:09,924] Starting training at step=8345012
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fe68427f-24bb-4cea-befc-4c8085dfbafa">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="674fd7ca-e2ed-4912-92f7-0b148da8c88a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("674fd7ca-e2ed-4912-92f7-0b148da8c88a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("b77b9b13-ac8d-49a7-86b0-98c4e25cce01", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("674fd7ca-e2ed-4912-92f7-0b148da8c88a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '674fd7ca-e2ed-4912-92f7-0b148da8c88a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6fc08dc9-5d7e-41ef-9f0e-73ccbc4e198d":{"roots":{"references":[{"attributes":{"callback":null,"end":11.0,"start":-1.0},"id":"3859e268-ea20-42c3-8423-d2e29e9cebf7","type":"Range1d"},{"attributes":{},"id":"5cfe72f8-fa14-4e48-81bb-1f88a66097ba","type":"BasicTicker"},{"attributes":{"formatter":{"id":"151d1455-3892-4d78-9c6c-e7e790e02fb1","type":"BasicTickFormatter"},"plot":{"id":"fa0660ab-3da1-445d-b3cb-1733d088ad54","subtype":"Figure","type":"Plot"},"ticker":{"id":"32f5ab8a-4ecb-442e-a0bb-e17f1e69b412","type":"BasicTicker"}},"id":"7b4a1f35-f94c-4963-a144-0d7251147698","type":"LinearAxis"},{"attributes":{"plot":{"id":"50eaf499-9c85-4adf-85b4-34eec9fed876","subtype":"Figure","type":"Plot"}},"id":"d610c1b1-dfd4-47a3-80c1-e8316afe9164","type":"HelpTool"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"field":"fill_color"},"line_color":{"value":"gold"},"line_width":{"field":"line_width"},"radius":{"field":"radius","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b842d573-02a2-43be-99b1-134ed5d76d07","type":"Circle"},{"attributes":{"plot":{"id":"50eaf499-9c85-4adf-85b4-34eec9fed876","subtype":"Figure","type":"Plot"},"ticker":{"id":"5cfe72f8-fa14-4e48-81bb-1f88a66097ba","type":"BasicTicker"}},"id":"6bebb6c2-42ff-4a7f-bd77-3a97271eef92","type":"Grid"},{"attributes":{"plot":{"id":"fa0660ab-3da1-445d-b3cb-1733d088ad54","subtype":"Figure","type":"Plot"}},"id":"5196291b-92ac-47cc-a41c-6d7f641ed893","type":"ResetTool"},{"attributes":{"data_source":{"id":"dd96c4cf-a7c1-495e-8d26-3a8a804407ff","type":"ColumnDataSource"},"glyph":{"id":"817e91e7-97ce-41d2-9e6e-125c97e49477","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"84c6fc19-c3ba-463f-bb62-d8674d2b680d","type":"Line"},"selection_glyph":null},"id":"347bcaf0-8ff4-4191-871d-5bc09f7c2eb6","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"728c7314-cf53-46cb-87b3-59d7821fb87f","type":"DataRange1d"},{"attributes":{"data_source":{"id":"468d0dd9-160e-4c51-81b4-11489447fa1e","type":"ColumnDataSource"},"glyph":{"id":"d2fbcc1c-340a-44cd-aca8-84e87de3de5a","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b4bca0b5-4733-4a86-a84d-2d541caf3ae1","type":"Line"},"selection_glyph":null},"id":"1d491239-66aa-4405-a324-22e063114954","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"59ec15b7-3ee2-46de-8ecd-f022d6b4cf7f","type":"BasicTickFormatter"},"plot":{"id":"50eaf499-9c85-4adf-85b4-34eec9fed876","subtype":"Figure","type":"Plot"},"ticker":{"id":"5cfe72f8-fa14-4e48-81bb-1f88a66097ba","type":"BasicTicker"}},"id":"918bb897-5820-4a4c-8bc1-97db73a5d142","type":"LinearAxis"},{"attributes":{},"id":"aa8af6f7-1417-401f-b99e-6009bb622528","type":"BasicTickFormatter"},{"attributes":{"align":"center","background_fill_color":{"value":"blue"},"plot":null,"text":"step #0","text_color":{"value":"orange"},"text_font_size":{"value":"25px"}},"id":"f952fc21-bb94-4ce3-a576-ded97a4ad672","type":"Title"},{"attributes":{"plot":{"id":"fa0660ab-3da1-445d-b3cb-1733d088ad54","subtype":"Figure","type":"Plot"}},"id":"b675ce8d-a2e2-43e9-a430-0e43fb5a9101","type":"WheelZoomTool"},{"attributes":{},"id":"c61ac2a1-c093-4c63-a3b5-76d5bf02aec6","type":"ToolEvents"},{"attributes":{"callback":null},"id":"d247dd72-b7ce-45dc-b88e-43ca0c8eca1f","type":"DataRange1d"},{"attributes":{"plot":{"id":"50eaf499-9c85-4adf-85b4-34eec9fed876","subtype":"Figure","type":"Plot"}},"id":"402e4a12-614a-4adc-92f1-4e808b94351b","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"fa0660ab-3da1-445d-b3cb-1733d088ad54","subtype":"Figure","type":"Plot"}},"id":"fc6a5e70-29a4-4675-80a8-2fe80628ee2e","type":"PanTool"},{"attributes":{},"id":"f57be5fa-eac1-4dd3-bdb9-bd7b6b532c09","type":"ToolEvents"},{"attributes":{"above":[{"id":"918bb897-5820-4a4c-8bc1-97db73a5d142","type":"LinearAxis"}],"left":[{"id":"822c0082-8c50-4ac1-9b5b-d290053dcc08","type":"LinearAxis"}],"renderers":[{"id":"918bb897-5820-4a4c-8bc1-97db73a5d142","type":"LinearAxis"},{"id":"6 ...
