# %%
from extension import config
import gym

env = gym.make(config.GAME_NAME)
N_S = env.observation_space.shape
N_A = env.action_space.n

print(N_S, ">>>>", N_A)
s = env.reset()
print(s.shape)
# Out:
# [2017-06-21 11:38:14,750] Making new env: tiny-rpg-man-v0
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e8b7ff1f-bec8-429e-a47d-2f27ea8c05cf">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="90f07490-aa5e-464c-80e8-27096a4e4c5f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("90f07490-aa5e-464c-80e8-27096a4e4c5f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("7dde5aca-154f-4c80-998c-198fea56cffb", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("90f07490-aa5e-464c-80e8-27096a4e4c5f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '90f07490-aa5e-464c-80e8-27096a4e4c5f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"20998675-9a2c-48ae-b788-40baaab48b84":{"roots":{"references":[{"attributes":{"plot":{"id":"e76bfed1-a218-491f-89fd-dc6144ef5398","subtype":"Figure","type":"Plot"}},"id":"c3df1e11-ff89-48b9-908a-a15269bf5316","type":"PanTool"},{"attributes":{"plot":{"id":"676ab05f-1512-464f-8559-48b32d2a547a","subtype":"Figure","type":"Plot"}},"id":"6bc54028-f2c4-4d60-981b-6d5a486d6b3f","type":"HelpTool"},{"attributes":{},"id":"1783b10c-3b79-48a2-b98f-09dc4403cec5","type":"ToolEvents"},{"attributes":{"align":"center","background_fill_color":{"value":"blue"},"plot":null,"text":"step #0","text_color":{"value":"orange"},"text_font_size":{"value":"25px"}},"id":"e95b8728-6b61-417b-bb25-1c3650223a69","type":"Title"},{"attributes":{"sizing_mode":"scale_width","toolbar_location":"above","tools":[{"id":"cd326937-becc-4fd5-8c7a-a939345c77ed","type":"PanTool"},{"id":"e3c2e8ce-6113-4368-8657-7c36276f9850","type":"WheelZoomTool"},{"id":"b05598e4-0bdf-4df8-b864-97aeb4f65ba0","type":"BoxZoomTool"},{"id":"dda0ee75-fdb1-4aee-95e1-3658e99f6322","type":"SaveTool"},{"id":"1208df55-4f43-474c-89b8-783d3c47af9a","type":"ResetTool"},{"id":"6bc54028-f2c4-4d60-981b-6d5a486d6b3f","type":"HelpTool"},{"id":"c3df1e11-ff89-48b9-908a-a15269bf5316","type":"PanTool"},{"id":"0e26239f-8f60-41b9-a8f5-28b4a0c42d38","type":"WheelZoomTool"},{"id":"5f4611e4-5834-4cbd-9c35-97df47560134","type":"BoxZoomTool"},{"id":"b79ed6bd-9d89-45f4-b7f3-95af3969650a","type":"SaveTool"},{"id":"e10edf42-5a59-4df7-b325-9b1bb165a1ff","type":"ResetTool"},{"id":"1621cb36-5096-484d-873d-d0c9f7b1a589","type":"HelpTool"}]},"id":"841662e3-7a19-40fc-aa83-92ec887cf312","type":"ToolbarBox"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6d46c8b9-8a93-484d-bcaf-1a81ec2348d7","type":"BoxAnnotation"},{"attributes":{},"id":"cb70f12f-ea99-4369-aba5-970d92ffb52f","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"676ab05f-1512-464f-8559-48b32d2a547a","subtype":"Figure","type":"Plot"},"ticker":{"id":"88b27caf-7e7d-4b3c-9691-e8ba19f41fdb","type":"BasicTicker"}},"id":"ce45cb3d-700c-4f6e-b283-abb0ca88ff32","type":"Grid"},{"attributes":{"children":[{"id":"9b01d9b1-2526-434b-9e9b-8a46949ec2e7","type":"Row"}]},"id":"9924eaf6-d4d7-4f9f-bac4-854147cda60f","type":"Column"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1],"y":[0]}},"id":"5e01077d-5c72-48d6-9e74-01b7f6eb083f","type":"ColumnDataSource"},{"attributes":{},"id":"21156b23-8a2a-4fdb-8c44-6d9ed3521fc2","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"841662e3-7a19-40fc-aa83-92ec887cf312","type":"ToolbarBox"},{"id":"9924eaf6-d4d7-4f9f-bac4-854147cda60f","type":"Column"}]},"id":"06d93424-6749-46d1-b012-25b67fc641b8","type":"Column"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c3df1e11-ff89-48b9-908a-a15269bf5316","type":"PanTool"},{"id":"0e26239f-8f60-41b9-a8f5-28b4a0c42d38","type":"WheelZoomTool"},{"id":"5f4611e4-5834-4cbd-9c35-97df47560134","type":"BoxZoomTool"},{"id":"b79ed6bd-9d89-45f4-b7f3-95af3969650a","type":"SaveTool"},{"id":"e10edf42-5a59-4df7-b325-9b1bb165a1ff","type":"ResetTool"},{"id":"1621cb36-5096-484d-873d-d0c9f7b1a589","type":"HelpTool"}]},"id":"f9dc4d71-386d-455c-9b8e-bf479a87c9bc","type":"Toolbar"},{"attributes":{},"id":"88b27caf-7e7d-4b3c-9691-e8ba19f41fdb","type":"BasicTicker"},{"attributes":{"formatter":{"id":"f835902c-a3b5-41d1-be4a-28445d7c0259","type":"BasicTickFormatter"},"plot":{"id":"676ab05f-1512-464f-8559-48b32d2a547a","subtype":"Figure","type":"Plot"},"ticker":{"id":"cb70f12f-ea99-4369-aba5-970d92ffb52f","type":"BasicTicker"}},"id":"f92b03a8-f6a6-4977-9b2f-9d5d462b8649","type":"LinearAxis"},{"attributes":{"plot":{"id" ...
# () >>>> 1
# (14,)

# %%
import main
main.run()
